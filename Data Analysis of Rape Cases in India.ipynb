# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\Rape cases.csv")
df.head()
# Out:
#   Category States/ UTs/ Cities  No. of Incest (Rape) Cases Reported  \
# 0    State      Andhra Pradesh                                    7
# 1    State   Arunachal Pradesh                                    0
# 2    State               Assam                                    1
# 3    State               Bihar                                    2
# 4    State        Chhattisgarh                                   63
#
#    No. of Victims of Incest (Rape) - Upto 10 Years  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                2
#
#    No. of Victims of Incest (Rape) - 10 - 14 Years  \
# 0                                                0
# 1                                                0
# 2                                                0
# ...

# %%
df.rename(columns={"States/ UTs/ Cities":"Cities",'No. of Incest (Rape) Cases Reported':"Incest_Rape_Cases_Reported",
       'No. of Victims of Incest (Rape) - Upto 10 Years':"Incest_Rape_upto_10years",
       'No. of Victims of Incest (Rape) - 10 - 14 Years':"Incest_Rape_10-14years",
       'No. of Victims of Incest (Rape) - 14 - 18 Years':"Incest_Rape_14-18years",
       'No. of Victims of Incest (Rape) - 18 - 30 Years':"Incest_Rape_18-30years",
       'No. of Victims of Incest (Rape) - 30 - 50 Years':"Incest_Rape_30-50years",
       'No. of Victims of Incest (Rape) - Above 50 Years':"Incest_Rape_above_50years",
       'No. of Victims of Incest (Rape) - Total Victims':"Incest_Total_Victims",
       'No. of Other (Rape) Cases Reported':"Rape_Cases_Reported",
       'No. of Victims of Other (Rape) - Upto 10 Years':"Rape_Victims_upto_10years",
       'No. of Victims of Other (Rape) - 10 - 14 Years':"Rape_Victims_10-14years",
       'No. of Victims of Other (Rape) - 14 - 18 Years':"Rape_Victims_14-18years",
       'No. of Victims of Other (Rape) - 18 - 30 Years':"Rape_Victims_18-30years",
       'No. of Victims of Other (Rape) - 30 - 50 Years':"Rape_Victims_30-50years",
       'No. of Victims of Other (Rape) - Above 50 Years':"Rape_Victims_above_50years",
       'No. of Victims of Other (Rape) - Total Victims':"Total_Rape_Victims_of_Other",
       'No. of Rape Cases (Total) Reported':"Total_Rape_Cases_Reported",
       'No. of Victims of Rape Cases (Total) - Upto 10 Years':"Total_Rape_Victims_upto_10years",
       'No. of Victims of Rape Cases (Total) - 10 - 14 Years':"Total_Rape_Victims_10-14years",
       'No. of Victims of Rape Cases (Total) - 14 - 18 Years':"Total_Rape_Victims_14-18years",
       'No. of Victims of Rape Cases (Total) - 18 - 30 Years':"Total_Rape_Victims_18-30years",
       'No. of Victims of Rape Cases (Total) - 30 - 50 Years':"Total_Rape_Victims_30-50years",
       'No. of Victims of Rape Cases (Total) - Above 50 Years':"Total_Rape_Victims_above_50years",
       'No. of Victims of Rape Cases (Total) - Total Victims':"Total_Rape_Victims"},inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'Cities', 'Incest_Rape_Cases_Reported',
#        'Incest_Rape_upto_10years', 'Incest_Rape_10-14years',
#        'Incest_Rape_14-18years', 'Incest_Rape_18-30years',
#        'Incest_Rape_30-50years', 'Incest_Rape_above_50years',
#        'Incest_Total_Victims', 'Rape_Cases_Reported',
#        'Rape_Victims_upto_10years', 'Rape_Victims_10-14years',
#        'Rape_Victims_14-18years', 'Rape_Victims_18-30years',
#        'Rape_Victims_30-50years', 'Rape_Victims_above_50years',
#        'Total_Rape_Victims_of_Other', 'Total_Rape_Cases_Reported',
#        'Total_Rape_Victims_upto_10years', 'Total_Rape_Victims_10-14years',
#        'Total_Rape_Victims_14-18years', 'Total_Rape_Victims_18-30years',
#        'Total_Rape_Victims_30-50years', 'Total_Rape_Victims_above_50years',
#        'Total_Rape_Victims'],
#       dtype='object')

# %%
df.drop("Category",axis=1,inplace=True)

# %%
df.head(3)
# Out:
#               Cities  Incest_Rape_Cases_Reported  Incest_Rape_upto_10years  \
# 0     Andhra Pradesh                           7                         0
# 1  Arunachal Pradesh                           0                         0
# 2              Assam                           1                         0
#
#    Incest_Rape_10-14years  Incest_Rape_14-18years  Incest_Rape_18-30years  \
# 0                       0                       4                       3
# 1                       0                       0                       0
# 2                       0                       1                       0
#
#    Incest_Rape_30-50years  Incest_Rape_above_50years  Incest_Total_Victims  \
# 0                       0                          0                     7
# 1                       0                          0                     0
# 2                       0                          0                     1
#
#    Rape_Cases_Reported  ...  Rape_Victims_above_50years  \
# ...

# %%
df2=df.set_index("Cities")
df2
# Out:
#                    Incest_Rape_Cases_Reported  Incest_Rape_upto_10years  \
# Cities
# Andhra Pradesh                              7                         0
# Arunachal Pradesh                           0                         0
# Assam                                       1                         0
# Bihar                                       2                         0
# Chhattisgarh                               63                         2
# ...                                       ...                       ...
# Vadodara                                    0                         0
# Varanasi                                    0                         0
# Vijayawada                                  1                         0
# Vishakhapatnam                              0                         0
# Total (Cities)                             46                         4
#
#                    Incest_Rape_10-14years  Incest_Rape_14-18years  \
# Cities
# ...

# %%
df.loc[[28,
        36,
        37,
        73]].filter(items=["Cities","Total_Rape_Victims_18-30years",
                                "Total_Rape_Victims_30-50years",'Total_Rape_Cases_Reported']).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_9b597_row0_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_9b597_row0_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_9b597_row0_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_9b597_row1_col1, #T_9b597_row1_col2, #T_9b597_row1_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9b597_row2_col1, #T_9b597_row2_col2, #T_9b597_row2_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9b597_row3_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9b597_row3_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_9b597_row3_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9b597">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b597_level0_col0" class="col_heading level0 col0" >Cities</th>
# ...

# %%
df2.iloc[[28,36,
          37,73]].filter(items=["Cities","Total_Rape_Victims_18-30years",
                                "Total_Rape_Victims_30-50years",'Total_Rape_Cases_Reported']).plot(kind='bar')
plt.xticks(rotation=0)
plt.xlabel("All Over India")
# Out:
# Text(0.5, 0, 'All Over India')

# %%
df2.filter(items=["Rape_Victims_upto_10years","Rape_Victims_10-14years","Rape_Victims_18-30years","Rape_Victims_30-50years"]).head(10)
# Out:
#                    Rape_Victims_upto_10years  Rape_Victims_10-14years  \
# Cities
# Andhra Pradesh                            52                      110
# Arunachal Pradesh                          1                        0
# Assam                                      0                        0
# Bihar                                      9                       26
# Chhattisgarh                              30                      107
# Goa                                        4                        4
# Gujarat                                   17                       30
# Haryana                                   17                       24
# Himachal Pradesh                          10                       19
# Jammu & Kashmir                            0                        5
#
#                    Rape_Victims_18-30years  Rape_Victims_30-50years
# Cities
# Andhra Pradesh                         569                      128
# ...

# %%
df2.filter(items=["Rape_Victims_18-30years","Rape_Victims_30-50years"]).head(10).plot(kind="barh",color=["red","blue"])
# Out:
# <Axes: ylabel='Cities'>

# %%
df2.filter(items=["Rape_Victims_upto_10years","Rape_Victims_10-14years"]).head(10)
# Out:
#                    Rape_Victims_upto_10years  Rape_Victims_10-14years
# Cities
# Andhra Pradesh                            52                      110
# Arunachal Pradesh                          1                        0
# Assam                                      0                        0
# Bihar                                      9                       26
# Chhattisgarh                              30                      107
# Goa                                        4                        4
# Gujarat                                   17                       30
# Haryana                                   17                       24
# Himachal Pradesh                          10                       19
# Jammu & Kashmir                            0                        5

# %%
type(df2.filter(items=["Rape_Victims_upto_10years","Rape_Victims_10-14years"]).head(10))
# Out:
# pandas.core.frame.DataFrame

# %%
df2.filter(items=["Rape_Victims_upto_10years","Rape_Victims_10-14years"]).head(10).plot(kind="barh")
# Out:
# <Axes: ylabel='Cities'>

# %%
# df2.drop(["Total (All India)","Total (States)","Total (Cities)",

# %%
plt.style.use("dark_background")
df2.filter(["Total_Rape_Victims_18-30years",
            "Total_Rape_Victims_30-50years"]).sort_values(["Total_Rape_Victims_18-30years",
                                                           "Total_Rape_Victims_30-50years"],
                                                          ascending=[False,True]).head(10)[2:7].plot(kind="line",color=["cyan","coral"],
                                                                                                     marker=".",markersize=20)
# Out:
# <Axes: xlabel='Cities'>

# %%
df.filter(items=["Cities",
                 "Total_Rape_Victims",
                 "Total_Rape_Cases_Reported"]).sort_values(by="Total_Rape_Victims").head(10).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_374f2_row0_col1, #T_374f2_row0_col2, #T_374f2_row1_col1, #T_374f2_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_374f2_row2_col1, #T_374f2_row2_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_374f2_row3_col1, #T_374f2_row3_col2, #T_374f2_row4_col1, #T_374f2_row4_col2, #T_374f2_row5_col1, #T_374f2_row5_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_374f2_row6_col1, #T_374f2_row6_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_374f2_row7_col1, #T_374f2_row7_col2, #T_374f2_row8_col1, #T_374f2_row8_col2 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_374f2_row9_col1, #T_374f2_row9_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_374f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_374f2_level0_col0" class="col_heading level0 col0" >Cities</th>
# ...

# %%
df.filter(items=["Cities",
                 "Total_Rape_Victims"]).sort_values(by="Total_Rape_Victims").head(10).plot(kind="bar",
                                                                                           x="Cities",
                                                                                          color="cyan")


plt.xticks(rotation=30)
plt.title("Top 10 Low Rape Cases")
# Out:
# Text(0.5, 1.0, 'Top 10 Low Rape Cases')

# %%
df2.drop(["Total (All India)","Total (States)","Total (Cities)","Total (UTs)"],axis=0,inplace=True)

# %%
df2.filter(items=["Incest_Rape_Cases_Reported",
                  "Incest_Rape_18-30years","Incest_Rape_30-50years"
                 ]).sort_values(by="Incest_Rape_Cases_Reported",ascending=False).head(8)
# Out:
#                 Incest_Rape_Cases_Reported  Incest_Rape_18-30years  \
# Cities
# West Bengal                            114                      81
# Chhattisgarh                            63                      14
# Madhya Pradesh                          49                      14
# Rajasthan                               42                      15
# Maharashtra                             40                      13
# Kerala                                  21                      11
# Delhi                                   18                       5
# Delhi (city)                            17                       5
#
#                 Incest_Rape_30-50years
# Cities
# West Bengal                         25
# Chhattisgarh                         6
# Madhya Pradesh                       4
# Rajasthan                            3
# Maharashtra                          9
# Kerala                               0
# Delhi                                0
# ...

# %%
df2.filter(items=["Incest_Rape_Cases_Reported",
                  "Incest_Rape_18-30years","Incest_Rape_30-50years"
                 ]).sort_values(by="Incest_Rape_Cases_Reported",ascending=False).head(8).plot(kind="line")
plt.xticks(rotation=30)
# Out:
# (array([-1.,  0.,  1.,  2.,  3.,  4.,  5.,  6.,  7.,  8.]),
#  [Text(-1.0, 0, 'Delhi (city)'),
#   Text(0.0, 0, 'West Bengal'),
#   Text(1.0, 0, 'Chhattisgarh'),
#   Text(2.0, 0, 'Madhya Pradesh'),
#   Text(3.0, 0, 'Rajasthan'),
#   Text(4.0, 0, 'Maharashtra'),
#   Text(5.0, 0, 'Kerala'),
#   Text(6.0, 0, 'Delhi'),
#   Text(7.0, 0, 'Delhi (city)'),
#   Text(8.0, 0, '')])

# %%
df2.filter(items=["Incest_Rape_Cases_Reported",
                  "Incest_Rape_18-30years","Incest_Rape_30-50years"
                 ]).sort_values(by="Incest_Rape_Cases_Reported",ascending=False).head(8)
# Out:
#                 Incest_Rape_Cases_Reported  Incest_Rape_18-30years  \
# Cities
# West Bengal                            114                      81
# Chhattisgarh                            63                      14
# Madhya Pradesh                          49                      14
# Rajasthan                               42                      15
# Maharashtra                             40                      13
# Kerala                                  21                      11
# Delhi                                   18                       5
# Delhi (city)                            17                       5
#
#                 Incest_Rape_30-50years
# Cities
# West Bengal                         25
# Chhattisgarh                         6
# Madhya Pradesh                       4
# Rajasthan                            3
# Maharashtra                          9
# Kerala                               0
# Delhi                                0
# ...

# %%
colors=["orange","lime","cyan"]

# %%
df2.filter(items=["Incest_Rape_Cases_Reported",
                  "Incest_Rape_18-30years","Incest_Rape_30-50years",
                 ]).sort_values(by="Incest_Rape_Cases_Reported",
                                ascending=False).head(10)[2:5].plot(kind="barh",color=["lime","dimgray","orangered"])
plt.ylabel("States")
plt.title("Top 3 States")
# Out:
# Text(0.5, 1.0, 'Top 3 States')

# %%
# df2.drop(["Total (All India)","Total (States)","Total (Cities)","Total (UTs)"],axis=0,inplace=False)
